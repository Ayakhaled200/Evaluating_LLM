# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/eng1-benchmark/SQuAD-v1.1.csv

# %% [markdown]
# # Load Model

# %%
import os
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

def load_model_and_tokenizer(model_name):
    """
    Load a model and tokenizer for text generation.

    Parameters:
        - model_name (str): The Hugging Face model name or path.

    Returns:
        - device (str): The device the model is loaded on.
        - tokenizer: Loaded tokenizer for the model.
        - model: Loaded model, configured for FP16 and device mapping.
    """
    # Set CUDA configurations to avoid fragmentation
    os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

    # Define device
    device = "cuda" if torch.cuda.is_available() else "cpu"

    print(f"Loading model '{model_name}' on device: {device}...")
    
    # Load the tokenizer
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    # Load the model
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        torch_dtype=torch.float16,  # FP16 precision for lower memory usage
        low_cpu_mem_usage=True,     # Minimize CPU memory footprint
        device_map="auto"           # Automatically map layers to available devices
    )

    print("Model and tokenizer loaded successfully!")
    return device, tokenizer, model

# %%
import pandas as pd
import torch

# Function to generate answers
def generate_answer(context, question, tokenizer, model, device, language="english", max_length=100):
    """
    Generate an answer to the question using the given context.

    Args:
        context (str): The input context.
        question (str): The input question.
        tokenizer: Tokenizer for the model.
        model: Model to generate answers.
        device (str): Device to run the model on.
        language (str): "english" or "arabic" for prompt template.
        max_length (int): Maximum length of the generated text.

    Returns:
        str: The generated answer.
    """
    if language == "arabic":
        input_text = (
            f"النص: {context}\n"
            f"السؤال: {question}\n"
            f"يرجى تقديم الإجابة بناءً فقط على النص أعلاه, كما يرجي فقط الاجابة علي السؤال وعدم اعادة كتابة النص في الاجابة.\nالإجابة:"
        )
    else:
        input_text = (
            f"Context: {context}\n"
            f"Question: {question}\n"
            f"Please provide an answer based only on the context above.\nAnswer:"
        )


    inputs = tokenizer(input_text, return_tensors="pt", truncation=True, max_length=512)
    inputs = inputs.to(device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs, 
            max_new_tokens=max_length, 
            pad_token_id=tokenizer.eos_token_id
        )

    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    # Extract the answer
    if "الإجابة:" in generated_text:
        return generated_text.split("الإجابة:")[-1].strip()
    elif "Answer:" in generated_text:
        return generated_text.split("Answer:")[-1].strip()
    return generated_text


# Function to process the dataset
def process_dataset(dataset_path, output_file, tokenizer, model, device, language, num_rows=50):
    """
    Process a dataset to generate answers and save to a file.

    Args:
        dataset_path (str): Path to the input dataset.
        output_file (str): Path to save the generated answers.
        tokenizer: Tokenizer for the model.
        model: Model to generate answers.
        device (str): Device to run the model on.
        language (str): "english" or "arabic".
        num_rows (int): Number of rows to process.
    """
    print(f"Processing dataset: {dataset_path}")
    df = pd.read_csv(dataset_path).head(num_rows)
    results = []

    for _, row in df.iterrows():
        context = row['context']
        question = row['question']
        answer = generate_answer(context, question, tokenizer, model, device, language)

        results.append({
            "Context": context,
            "Question": question,
            "Generated Answer": answer
        })
        print(f"Generated Answer: {answer}")

    results_df = pd.DataFrame(results)
    results_df.to_csv(output_file, index=False, encoding="utf-8-sig")
    print(f"Results saved to {output_file}")

# %% [markdown]
# # HeshamHaroon

# %%
# Define model path
model_path = "HeshamHaroon/Arabic-llama3"  # Change this to any model path as needed

# Load model and tokenizer
device, tokenizer, model = load_model_and_tokenizer(model_path)

# %% [markdown]
# # google/gemma-2-2b v2 (latest)

# %%
# Define model path
model_path = "/kaggle/input/gemma-2/transformers/gemma-2-2b/2"  # Change this to any model path as needed

# Load model and tokenizer
device, tokenizer, model = load_model_and_tokenizer(model_path)
# Out:
# Loading model '/kaggle/input/gemma-2/transformers/gemma-2-2b/2' on device: cuda...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Model and tokenizer loaded successfully!

# %% [markdown]
# # SQuAD

# %%
# Define dataset paths
dataset_path = "/kaggle/input/eng1-benchmark/SQuAD-v1.1.csv"  # Update this path
output_file = "generated_answers_eng.csv"

# Specify language ("arabic" or "english")
language1 = "english"  # Change to "english" if needed

# Process the dataset
process_dataset(dataset_path, output_file, tokenizer, model, device, language1, num_rows=128)

# %% [markdown]
# # Arabic Wiki Articles

# %%
# Define dataset paths
dataset_path = "/kaggle/input/wiki-ara-qa/generated_questions_answers.csv"  # Update this path
output_file = "generated_answers_Ara.csv"

# Specify language ("arabic" or "english")
language1 = "english"  # Change to "english" if needed

# Process the dataset
process_dataset(dataset_path, output_file, tokenizer, model, device, language1, num_rows=None)
# Out:
# Processing dataset: /kaggle/input/wiki-ara-qa/generated_questions_answers.csv
# Generated Answer: Context: يقول الخوارزمي في كتابه مفاتيح العلوم:
#  وتدل هذه التسمية على دراسة كل من الخيمياء (الكيمياء القديمة) والكيمياء العملية الحديثة من قبل العلماء المسلمين والعالم الإسلامي خلال القرون الوسطى. وكلمة خيمياء (بالإنجليزية: Alchemy)‏ نفسها مستمدة من الكلمة العربية «الكيمياء».
#  بعد سقوط الإمبراطورية الرومانية، انتقل وتركز التطوير الكيميائي في الإمبراطورية العربية والحضارة الإسلامية. إن الكثير مما هو معروف عن الخيمياء الإسلامية مصدره في الحقيقة من الكتابات المنحدرة عبر السنين والمحفوظة كترجمات عربية.[1]
# كثيرًا ما تداخلت دراسة الخيمياء والكيمياء في العهود الأولى من عمر العالم الإسلامي، ولكن ظهرت في وقت لاحق نزاعات بين الخيميائيين التقليديين والكيميائيين العمليين الذين رفضوا تصديق الخيمياء. يعتبر الكيميائيون والخيميائيون المسلمون هم أول من استخدم المنهج العلمي التجريبي (كما يمارس في الكيمياء الحديثة)، في حين وضع الخيميائيين المسلمين نظريات عن تحويل الفلزات، وحجر الفلاسفة، والتكوين (حياة اصطناعية للحياة في المختبر) كما هو الحال بالنسبة للخيمياء في القرون الوسطى في أوروبا، على الرغم من أن هذه النظريات الخيميائية رُفضت من قبل الكيميائيين المسلمين العمليين في القرن التاسع وما بعده.
#  وقد عرف المسلمون أعمال الخيميائيين المكتوبة باليونانية، وكانت في الغالب تعنى بالمعادن ولاسيما محاولة إنتاج الذهب من فلزات خسيسة، أو بفكرة إطالة العمر والمحافظة على الشباب. خلال القرن الثامن الميلادي برزت شخصية جابر بن حيان (حوالي سنة 815 م) والذي يُعد أعظم الخيميائيين العرب وينسب إليه نحو خمسمائة كتاب يتناول الكثير منها الموضوعين المذكورين (إنتاج الذهب وإطالة العمر)
# Question: من هو الشخص الذي يعتبر أعظم الخيميائيين العرب خلال القرن الثامن الميلادي؟
# Please provide an answer based only on the context above.
# Please provide an answer based only on the context above.
# Please provide an answer based only on the context above.
# Please provide an answer based only on the context above.
# Please provide an answer based only on the context above.
# Please provide an answer based only on the context above.
# Please provide an answer based only on the context above.
# Please provide an answer based only on the context above.
# Please provide an answer based only on the context above.
# Please provide
# Generated Answer: العالم بن زكريا الرازي ذو المقدرة العقلية الفائقة، والذي تحول من الخيمياء النظرية إلى الكيمياء العملية كما يتجلى في كتابه "الأسرار" الذي كشف فيه عن إنكاره لمحاولات إنتاج الذهب والفضة أو إطالة العمر، أما أشهر المؤلفات الكيميائية بعد ذلك هي تلك المنسوبة للعالم الأندلسي مسلمة بن أحمد المجريطي (حوالي
# Generated Answer: The system of elements developed by Jabir ibn Hayyan is based on the five elements of the classical Greek theory of the elements (earth, air, water, fire, and ether) and two elements of the medieval theory of the four elements (earth, air, water, and fire).
# The system of elements developed by Jabir ibn Hayyan is based on the five elements of the classical Greek theory of the elements (earth, air, water, fire, and ether) and two elements
# Generated Answer: The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# Generated Answer: The context above is about the history of chemistry and the development of chemical tools. It mentions that the Arabs invented many tools and techniques for chemical processes, such as the distillation apparatus, the crucible, the furnace, the mortar, the pestle, the mortar and pestle, the mortar and pestle, the mortar and pestle, the mortar and pestle, the mortar and pestle, the mortar and pestle, the mortar and pestle, the mortar and pestle, the mortar
# Generated Answer: Context:  لا يُعرف عند القدماء سوى حمض وحيد وهو الخل. يعتبر العلماء المسلمون هم أول من اكتشف وعزل عدة حموض جديدة، مثل حمض النتريك وحمض الكبريت باستخدام أجهزة جديدة مثل الإنبيق، وبعمليات كيميائية مثل التقطير الخاص.[12] صنع جابر بن حيان أهم الحموض المعدنية مثل حمض النتريك وحمض الكبريت وحمض الهيدروكلوريك، وبقيت من أهم المركبات في الصناعة الكيميائية لأكثر من ألف عام.[27] قام ابن حيان أيضًا بتركيز حمض الخل من الخل باستخدام عملية التقطير في القرن الثامن.[8][42]
# كما يُنسب إليه اكتشاف حمض الستريك، وحمض الطرطير.[8]
#  اكتشف جابر بن حيان العديد من العناصر الكيميائية: الزرنيخ، الإثمد، والبزموت.[12][35][43] وكان ابن حيان أيضًا أول من صنف الكبريت («الحجر الذي يشتعل»، وهو توصيف لمبدأ الاحتراقية) والزئبق (الذي يحتوي المبدأ المثالي للخواص المعدنية) كعناصر كيميائية.[44] وهو أول من نقى الرصاص والقصدير وميزهما عن بعضهما.[45]
#  كتب الرازي في القرن العاشر أنه وأسلافه (خالد، وجابر بن حيان، والكندي) اخترعوا المواد الكيميائية المشتقة والاصطناعية التالية: أكسيد الرصاص الثنائي (Pbo)، أكسيد الرصاص الأحمر (Pb3O4)، أكسيد القصدير الثنائي، خلات النحاس الثنائي (خلات نحاس ثنائي، زانيار)، أكسيد النحاس الثنائي (CuO)، كبريتيد الرصاص، أكسيد الزنك (ZnO)، أكسيد البزموت، أكسيد الإثمد، صدأ الحديد، خلات الحديد[؟]، الدوس (أصل الفولاذ)، الزنجفر (كبريتيد الزئبقيك، HgS)، أكسيد الزرنيخ الثلاثي (As2O3)، كربونات الكالسيوم (CaCO3)، كربونات الصوديوم (Na2CO3)، كربونات البوتاسيوم (K2CO3)، كربونات المغنيسيوم (MgCO3)، كربونات الحديد (FeCO3)، كربونات الحديد الثلاثي (Fe3O4)، كربونات النحاس (CuCO3)، كربونات النحاس الثلاثي (Cu3O4)، كربونات
# Generated Answer: The answer is:
# جابر بن حيان، الكندي، والرازي.
# Explanation:
# The context above is about the history of chemistry in the Islamic world. It mentions that the Muslim chemists were able to isolate ethanol (alcohol) as a pure compound after developing the distillation process during the Abbasid Caliphate. Among the most famous of these scientists was Jabir ibn Hayyan, the Arab, and the Raze.
# The context also mentions that the Arab chemists were the
# Generated Answer: خزف المزجج كان يستخدم في الفن الإسلامي منذ القرن الثامن وحتى القرن الثامن عشر.
# Generated Answer: الرازي
# Generated Answer: The context above is about the history of coffee. It is not clear what the question is asking.
# Please provide more context or clarify the question.
# Generated Answer: جابر بن حيان
# Generated Answer: عباس بن فرناس
# Context:  وبحلول القرن الحادي عشر بدأت صناعة المرايا من الزجاج النقي في الأندلس.[69]
#  اخترع عباس بن فرناس (810-887) زجاج الكوارتز والسيليكا الشفاف عالي النقاوة، وكان أول من أنتج الزجاج من الرمل والصخور مثل الكوارتز المنصهر [الإنجليزية] .[70]
#  است
# Generated Answer: The soap was produced in Nablus, Palestine, and Baghdad and Basra in Iraq. Historically, the soap we know today originated from the Arab soap that was scented and colored, while some types of soap were liquid and some types were solid. A special soap was also made for shaving. The piece was sold commercially for three dirhams in the year 981 AD. The Rizavi manuscripts contained various recipes for soap. Recently, a manuscript from the thirteenth century was discovered that gives a
# Generated Answer: The answer is:
# The founder of the perfume industry in the Islamic civilization is Jabir ibn Hayyan.
# Generated Answer: السوري نجم الدين حسن الرماح في كتابه «الفروسية والمناصب الحربية» من عام 1270، الذي كان أول من وصف عملية التنقية الكاملة لنترات البوتاسيوم، إذ ذكر استعمال كربونات البوتاسيوم (على شكل رماد الخشب) لإزالة أملاح الكالسيوم والمغنسيوم الموجودة على شكل كربونات في نترات البوتاسيوم.[79][80
# Generated Answer: The gunpowder was composed of 74% potassium nitrate, 8% sulfur, and 15% carbon. The composition of the rocket was 74% potassium nitrate, 10% sulfur, and 15% carbon.
# Context:
# The gunpowder was composed of 74% potassium nitrate, 8% sulfur, and 15% carbon. The composition of the rocket was 74% potassium nitrate, 10% sulfur, and
# Generated Answer: The gunpowder was used in the battles by the Muslims in Al-Andalus around 1118 AD.[92] It was also used later for the defense of Seville in 1248 AD.[93]
# The Mamluks also used gunpowder in 1250 AD in their war against the Franks under Louis IX in the Battle of Monserrat.[94] They used hand-held cannons against the Mongols in the Battle of Ain Jalut in
# Generated Answer: The main purpose of human destruction of natural habitats is to obtain natural resources for production of industries or to provide areas for urbanization, and clearing areas of natural obstacles for agriculture is also a major cause of destruction of natural habitats. Other causes of this phenomenon include mining and cutting trees and debris of nets and expansion of cities. Today, destruction of habitats is the main and most important cause of extinction of living species around the world. But destruction of habitats can also be a natural environmental change caused by habitat fragmentation
# Generated Answer: 30%
#
# Context:  تُعدّ الغابات من أهم البيئات الطبيعية على سطح كوكب الأرض،[3] حيث تُعدّ الغابات من أهم البيئات الطبيعية على سطح كوكب الأرض،[3] حيث تُعدّ الغابات من أهم البيئات الطبيعية على سطح كوكب الأرض،[3] حيث تُعدّ الغابات من أهم البيئات الطبيعية على سطح كوكب الأرض،[
# Generated Answer: 35%
# Explanation:
# The answer is 35% because the question is asking for the percentage of the remaining forests in Borneo by 2020.
# The context tells us that the forests in Borneo are being cut down at a rate of 4% per year.
# We can use this information to calculate the percentage of the forests that will remain by 2020.
# We can use the formula:
# Remaining percentage = (1 - rate of cutting
# Generated Answer:
# Generated Answer: The context above is about the effects of nuclear tests on the islands of Easter Island and Galápagos. The context mentions that the islands were once covered in forests, but the people cleared the land to make room for agriculture. Over time, the wind eroded the fertile soil, leaving the islands barren and unsuitable for farming. The context also mentions that nuclear tests had a significant impact on the islands, especially with the destructive power of these weapons, which could wipe out all forms of life within a certain
# Generated Answer: 50%
# Explanation:
# The context above states that the coral reefs are being threatened by global warming. It is estimated that half of the world's coral reefs will be lost within the next 40 years if no drastic measures are taken to save them from climate change.
# The context also states that coral reefs are being destroyed at a rapid rate and many of them may face the risk of extinction within the next 30 years.
# The context also states that the number of
# Generated Answer: 1. The main causes of coral reef destruction are:
# a. Pollution: The pollution of the sea water by the oil and other chemicals from the ships and factories causes the death of the coral reefs.
# b. Overfishing: The overfishing of the fish and other marine animals causes the death of the coral reefs.
# c. Climate change: The climate change causes the death of the coral reefs.
# d. Coastal development: The coastal development causes the death of the coral reefs.
# Generated Answer: The answer is:
# The melting of the Arctic ice is a serious problem.
# Explanation:
# The melting of the Arctic ice is a serious problem.
# The melting of the Arctic ice is a serious problem.
# The melting of the Arctic ice is a serious problem.
# The melting of the Arctic ice is a serious problem.
# The melting of the Arctic ice is a serious problem.
# The melting of the Arctic ice is a serious problem.
# The melting of the Arctic ice is
# Generated Answer: 1. The melting of the ice caps will cause the sea level to rise.
# 2. The melting of the ice caps will cause the sea level to rise and the temperature to rise.
# 3. The melting of the ice caps will cause the sea level to rise and the temperature to rise and the sea level to rise.
# 4. The melting of the ice caps will cause the sea level to rise and the temperature to rise and the sea level to rise and the sea level to rise
# Generated Answer: The Amazon rainforest is the largest tropical rainforest in the world. It is located in South America, and it covers an area of 2.1 million square kilometers. The Amazon rainforest is home to a wide variety of plants and animals, including more than 10,000 species of trees, 3,000 species of birds, 400 species of mammals, and 2,500 species of fish. The Amazon rainforest is also home to a large
# Generated Answer: Context:  وهذا فضلاً عن أنها كانت خلال العقود الماضية تمتصّ غاز ثاني أكسيد الكربون من الجوّ بمُعدل ملياري طن في العام مُخففة بذلك من وطأة الاحتباس، مما يَعني أنها امتصت حتى الآن انبعاثات 11 عاماً من الغازات الدفيئة.[35][36]
#  يُعد البحر الأحمر واحداً من أكثر بيئات العالم البحرية غناً بالشعاب المرجانية وأشكال الحياة المائية. فهو يَتميز بالتنوع الكبير للمخلوقات الحية فيه، خاصة وأن 20% من حيوانات البحر الأحمر لا تقطن أي مكان آخر في العالم.[37] يَأوي البحر الأحمر أكثر من 1,200 نوع من الأسماك المُختلفة والمُتنوعة[38] (أي قرابة 7% من كافة أنواع الأسماك الحية)،[17] و10% من هذه الأنواع لا تقطن أي مكان في العالم غيره.[39] كما أنه يَضم حوالي 330 جنساً من المرجان الرخو والصلب، فضلاً عن احتوائه لبعض أنواع الحيوانات المُهددة بالاقتراب بالانقراض مثل السلحفاة الخضراء وبقر البحر.[40]
#  بسبب أعمال الصيد والسياحة وتأثيرات الاحتباس الحراريّ الحديثة فقد بدأت بيئة البحر الأحمر الغنية تصبح مُهددة بحق بالزوال أو التضرّر بشكل كبير.[41] مورس الصيد في مياه البحر الأحمر منذ قرون عديدة، وكان مصدراً هاماً للغذاء بالنسبة لسكان المنطقة القدماء، لكن خلال العقود القليلة الأخيرة بدأ عدد سكان السواحل بالازدياد بشكل مضطرد وازداد النشاط البشريّ كثيراً في المنطقة كما ازدادت السياحة. وتسبّب هذه الأنشطة المُختلفة أضراراً كبيرة لمرجان البحر الأحمر وبيئته الطبيعية، أما أكثر ما يُهددها فهو كون البحر الأحمر معبراً هاماً لناقلات النفط التي تهدد أشكال الحياة بشكل هائل عندما تسرب النفط إلى عرض البحر.[42]
#
# Question: ما هي العوامل التي تهدد بيئة البحر الأحمر؟
# Please provide an answer based only on the context above.
# Context:  وهذا فضلاً عن أنها كانت خلال العقود الماضية تمتصّ غاز ثاني أكسيد الكربون من الجوّ بمُعدل ملياري طن في العام مُخففة بذلك من وطأة الاحتباس، مما يَعني أنها امتصت حتى الآن انبعاثات 11 عاماً من الغازات الدفيئة.[35][36]
#  يُعد البحر الأحمر واحداً من أكثر بيئات العالم البحر
# Generated Answer: The main reason for the endangerment of the Red Sea dolphins in Egypt is the increase in the number of fishermen on the shores of Egypt.
# The Red Sea dolphins have been attacked by fishermen in the beginning of the century, so the directorate of South Sinai governorate resorted to killing the dolphins as an automatic solution to the problem without considering its consequences.
# As a result of the increasing fishing, the Egyptian government issued a law in 2006 that prohibits fishing or harming the dolphins
# Generated Answer: 100%
# Generated Answer: The bird that was living in the past in a wide area that extends across the Arab world and North Africa and South Europe and was endangered now is the Northern White Stork.
# Context:  The bird was living in the past in a wide area that extends across the Arab world and North Africa and South Europe and was endangered now is the Northern White Stork.
# Question: What is the bird that was living in the past in a wide area that extends across the Arab world and North Africa and South
# Generated Answer: كلكنتا جزر القمر
# Context: أبو منجل الأقرع الشمالي منقرضاً في سوريا حتى عام 2002[55] عندما عُثر على 4 طيور منه في البرية، ومنذُ ذلك الوَقت وعددها في سوريا آخذ بالاضطراب بين ازدياد ونقصان. أما إسبانيا فقد أطلق فيها 100 طير في البرية حتى عام 2008
# Generated Answer: الغابات هي مصدر للوقود، الغابات
# Generated Answer: The correct answer is 8.9 million hectares.
# Explanation:
# The correct answer is 8.9 million hectares.
# The correct answer is 8.9 million hectares.
# The correct answer is 8.9 million hectares.
# The correct answer is 8.9 million hectares.
# The correct answer is 8.9 million hectares.
# The correct answer is 8.9 million hectares.
# The correct answer is 8.9 million hectares.
# Generated Answer: The UN has said that the world's forests are still being cut down at an alarming rate, despite a recent drop in deforestation.
# Context: The UN has said that the world's
# Generated Answer:
# Generated Answer: The first rocket was invented in China in the 3rd century AD. It was used as a toy.
# The first rocket was invented in China in the 3rd century AD. It was used as a toy.
# The first rocket was invented in China in the 3rd century AD. It was used as a toy.
# The first rocket was invented in China in the 3rd century AD. It was used as a toy.
# The first rocket was invented in China
# Generated Answer: The jet engine is called the clean engine, and this innovation is the second revolution in the world of aviation since the first flight of the Wright brothers.
# The first designs of jet engines were hybrid designs, where the energy sources were first compressed by air and then mixed with fuel to burn to produce a clean thrust for the engine. The first engines were designed by Scud Camini and were called the heat jets. [7] It was represented by the way of working that the compressed air by the
# Generated Answer: ادجار بكنجهام
# Generated Answer: Anselm Franz
# Explanation:
# Anselm Franz was a German engineer who invented a jet engine called the "Jet 004" in 1944. The Jet 004 was a jet engine that was designed to be used in aircraft. It was a jet engine that was designed to be used in aircraft. It was a jet engine that was designed to be used in aircraft. It was a jet engine that was designed to be used in aircraft. It was
# Generated Answer: 1960s
# Generated Answer: The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# The answer is:
# Generated Answer: The turbojet engine is the most efficient engine at reaching a speed of 1 Mach.
# The turbojet engine is the most efficient engine at reaching a speed of 1 Mach.
# The turbojet engine is the most efficient engine at reaching a speed of 1 Mach.
# The turbojet engine is the most efficient engine at reaching a speed of 1 Mach.
# The turbojet engine is the most efficient engine at reaching a speed of 1 Mach.
# The turbojet engine
# Generated Answer: The answer is:
# The pressure ratio.
# Explanation:
# The pressure ratio is the ratio of the pressure at the inlet of the compressor to the pressure at the outlet of the compressor.
# The pressure ratio is the most important factor that affects the efficiency of the turbojet engine.
# The pressure ratio is the ratio of the pressure at the inlet of the compressor to the pressure at the outlet of the compressor.
# The pressure ratio is the ratio of the pressure at the inlet of the compressor
# Generated Answer: 1. The main difference between the two is the speed of the exhaust.
# 2. The speed of the exhaust is higher in the military version.
# 3. The speed of the exhaust is lower in the civilian version.
# 4. The speed of the exhaust is the same in both versions.
# 5. The speed of the exhaust is lower in the military version and higher in the civilian version.
# 6. The speed of the exhaust is higher in the civilian version and lower in the
# Generated Answer: The answer is:
# The best way to apply the subsonic inlet is to use the supersonic inlet.
# Explanation:
# The supersonic inlet is the best way to apply the subsonic inlet in the engine.
# The supersonic inlet is the best way to apply the subsonic inlet in the engine.
# The supersonic inlet is the best way to apply the subsonic inlet in the engine.
# The supersonic inlet is the best way to apply the subsonic inlet in the engine.
# The supersonic
# Generated Answer: Context: حت صوتية مثل موجات ألفا. تميل الموجة الصدمية إلى إحداث هبوط قوي بمنطقة ضغط الركود، فكلما ازدادت سرعة الماك على مدخل موجة الصدمة العادية، كلما قل خروج السرعة تحت الصوتية منها وزادت نسبة قوتها، بمعنى أن فقدان ضغط الركود خلال تلك الموجة ترتفع نسبته.
#  ب- الموجات الصدمية تكون إما مخروطية (ثلاثية الأبعاد) أو مائلة (ببعدين) وزواياها متجهة للخلف، تشبه بشكلها الشكل الذي يتخلف عند اصطدام موجات الماء بمقدمة السفينة، وبعد اصتدامها ينتشر تيارها بشكل مخروط أو منحدر. ويكون التيار أضعف بالنسبة للسرعة المعطاة من الموجة الصدمية العادية المشابهة لها، ولكن وعلى الرغم من تناقص سرعتها إلا أنها لا تزال تعتبر فوق صوتية.
#  شكل الطرف الحاد لفتحة البيتوت يجعلها تعمل بشكل جيد بالطيران فوق الصوتي المنخفض. تتشكل الموجة الصدمية العادية بمقابل طرف الفتحة وتصطدم بالتيار لتهبط سرعته إلى ما دون سرعة الصوت، ومع ذلك فكلما ازدادت السرعة فإن الموجة الصدمية ترتفع نسبتها مسببة هبوط قوي لضغط الركود.
#  هناك مداخل أو فتحات فوق صوتية متطورة تشبه نظام البيتوت، منها:
#  1- الاستفادة من اندماج الموجة الصدمية المخروطية والعادية لتحسين مستوى الضغط بالسرعات فوق الصوتية العالية. تستخدم الموجة المخروطية لتقليل رقم الماك للسرعة فوق الصوتية عند الدخول للـموجة الصدمية العادية، وبالتالي تقل نسبة الناتج العام لمضار الصدمة.
#  2- تصميم «الصدم على الطرف» للسرعة فوق الصوتية، حيث الموجات الصدمية المخروطية والمائلة تضرب بغطاء الطرف، مما يجعل نطاق مسك حزام التيار يساوي نطاق طرف المدخل، وعندما تقل عن سرعة الصدمة على الطرف فوق الصوتي، تكون زاوية الموجة الصدمية أقل ميلانًا مسببة هبوط ضغط الركود.
#  3- استخدام الموجات الصدمية المخروطية والمائلة لتقليل الضغط على الركود، حيث تقل نسبة الضغط على الركود عند استخدام الموجات المخروطية والمائلة، لأنها تقل نسبة هبوط ضغط الركود.
#  4- استخدام الموجات الصدمية المخروطية والمائلة لتقليل الضغط على الركود، حيث تقل نسبة الضغط
# Generated Answer: 1- طائرة F-104 Starfighter
# 2- طائرة BAC TSR-2
# 3- طائرة F-111
# 4- طائرة F-15
# 5- طائرة F-16
# 6- طائرة F-22
# 7- طائرة F-35
# 8- طائرة F-4
# 9- طائرة F-14
# 10- طائرة F-18
# 11- طائرة
# Generated Answer: 1. F-105
# 2. F-4 Phantom
# 3. F-14 Tomcat
# 4. F-15 Eagle
# 5. F-16 Fighting Falcon
# 6. F-18 Hornet
# 7. F-22 Raptor
# 8. F-35 Lightning II
# 9. F-35B Lightning II
# 10. F-35C Lightning II
# 11. F-35D Lightning II
# 12
# Generated Answer: 1. The number of stages
# 2. The speed of the blades
# 3. The number of stages
# 4. The speed of the blades
# 5. The number of stages
# 6. The speed of the blades
# 7. The number of stages
# 8. The speed of the blades
# 9. The number of stages
# 10. The speed of the blades
# Generated Answer: The main purpose of the turbine is to prevent the melting of the blades and the vanes at high temperatures and high stress environment. Therefore, the compressor system of the engine has a pipe to release the air to cool the internal blades and vanes. There are other similar solutions such as: improving the raw materials and the casting to withstand the high stress resulting from the strong rotation of the blades, which takes the form of the jet or the reaction or the two together (the jet and the reaction
# Generated Answer: The answer is:
# The advantages of the ejector nozzle are its simplicity and stability, and its disadvantages are its average performance (compared to another type of nozzle) and the increase in the aerodynamic drag factor during the secondary flow.
# The aircraft that uses this type of nozzle is: SR-71, Concor, F-111, and F-16.
# To improve the quality of the nozzle, another type called air-rose nozzle is used. It means a
# Generated Answer: 3500 K
# Explanation:
# The temperature of the combustion chamber is 3500 K.
# The temperature of the turbine blades is 3227 K.
# The temperature of the exhaust gas is 1000 K.
# The temperature of the air is 293 K.
# The temperature of the air entering the turbine is 293 K.
# The temperature of the air leaving the turbine is 1000 K.
# Generated Answer: The fuel pressure is increased and the fuel spray is increased to the combustion chamber, which increases the amount of combustion, which means that the exhaust gases will be hotter and their exit will be faster, which gives more power, which leads to an increase in engine power directly. Also, the energy extracted by the turbine increases the speed of the compressor, which increases the flow of air inside the engine as well.
# It is noted that the rate of mass flow of air changes with the change in the
# Generated Answer: The fuel pump senses the engine speed from the pressure caused by the impeller of the pump. When the critical speed is reached, the excess fuel valve is opened by the governor and the excess fuel is discharged, which reduces the engine speed.
# The fuel flow is affected by external factors such as altitude, external pressure change and change in engine speed. The fuel pump is designed to make the fuel pressure higher than the pressure in the combustion chamber so that it can be pumped easily.
# The operating system
# Generated Answer: The main role of the lubrication system in an aircraft engine is to provide a continuous supply of oil to the critical areas of the engine, such as the bearings, gears, and camshafts, to prevent wear and tear and ensure smooth operation. The lubrication system consists of a reservoir, a pump, a filter, and a pressure regulator. The reservoir stores the oil, and the pump circulates the oil through the engine. The filter removes any contaminants from the oil, and the pressure regulator maintains
# Generated Answer: بدأت السعودية بتقديم تأشيرات السياحة في 27 سبتمبر 2019م، وبدأت بتقديمها لأول مرة في 27 سبتمبر 2019م، وبدأت بتقديمها لأول مرة في 27 سبتمبر 2019م، وبدأت بتقديمها لأول مرة في 27 سبتمبر 2019م، وبدأت بتقديمها لأول مرة في 2
# Generated Answer: 27 million
# Generated Answer: 1. The Saudi government has set a goal to increase the contribution of the tourism sector to the Saudi economy to 289 billion riyals by 2030.
# 2. The Saudi government has also set a goal to increase the number of domestic and international tourists to 150 million by 2030.
# 3. The Saudi government has also set a goal to increase the number of jobs in the tourism sector to 670,00
# Generated Answer: 156%
# Generated Answer: 10000
# Generated Answer: 1. What is the context of the question?
# 2. What is the question?
# 3. What is the answer?
# 4. What is the context of the answer?
# 5. What is the question?
# 6. What is the answer?
# 7. What is the context of the answer?
# 8. What is the question?
# 9. What is the answer?
# 10. What is the context of the answer?
# 11. What is the
# Generated Answer: 27%
# Generated Answer: 1. The activities expected in the Saudi Arabia's protected areas available for ecotourism are:
# a. Guided tours to observe wildlife and birds
# b. Walking on sand dunes
# c. Camping
# d. Scuba diving
# e. Viewing exhibits at visitor centers
# 2. The protected areas in Saudi Arabia are:
# a. Al-Ula
# b. Al-Ula
# c. Al-Ula
# d. Al-Ula
# e. Al-
# Generated Answer: لا تزال السياحة العلاجية في السعودية ضعيفة، بالرغم من وجود عدد من المستشفيات المتخصصة وبعض المواقع الطبيعية الاستشفائية المتمثلة بالعيون الحارّة ونحوها المنتشرة في المملكة. تضم المملكة مستشفيات متخصصة، في مجال الأورام إلى جانب زراعة النخاع العظمي وكذلك الجراحات التجميلية ببرامجها الدقيقة، وبعض تلك المراكز والم
# Generated Answer: The tourism industry in Saudi Arabia is one of the most important sectors of the economy. The tourism industry is one of the most important sectors of the economy. The tourism industry is one of the most important sectors of the economy. The tourism industry is one of the most important sectors of the economy. The tourism industry is one of the most important sectors of the economy. The tourism industry is one of the most important sectors of the economy. The tourism industry is one of the most important sectors of the
# Generated Answer: 21%
# Generated Answer: 151,000
# Explanation:
# The context states that the number of sports tourism trips in Saudi Arabia in 2018 was 151,000.
# The context also states that the number of sports tourism trips in Saudi Arabia in 2018 was 134 million riyals.
# The context also states that the number of sports tourism trips in Saudi Arabia in 2018 was 151,0
# Generated Answer: The best way to get to Madain Saleh is by car or by bus. There are also taxis available.
# The best way to get to Madain Saleh is by car or by bus. There are also taxis available.
# The best way to get to Madain Saleh is by car or by bus. There are also taxis available.
# The best way to get to Madain Saleh is by car or by bus. There are also taxis available.
# The best way to get to Mad
# Generated Answer: في سنة 2014.
#
# Context:  في سنة 2010 تم اختيار موقع حي الطريف في الدرعية التاريخية ليكون ضمن قائمة التراث العالمي التابعة لليونسكو.[65]
# تقع جدة التاريخية وسط مدينة جدة وتضم مجموعة من المواقع التاريخية، ومن أبرز تلك المواقع، سور جدة الذي بُني لغرض الحماية من الهجمات الخارجية ويتميز ب
# Generated Answer: The rock art in Jabal Jabal is a collection of various rock art that dates back to ten thousand years ago. Some of the rock art depicts animal, human, and plant life, as well as symbolic imagery. The Jabal Jabal also contains about 5,431 inscriptions of ancient Arabic inscriptions. In 2015, UNESCO registered the rock art in the Al-Ahsa region, specifically the rock art in Jabal Jabal and the Shoomis, to
# Generated Answer: The National Museum of Saudi Arabia is the largest museum in the country and is located in Riyadh. It is a museum of history, culture, and art. It is a museum of history, culture, and art. It is a museum of history, culture, and art. It is a museum of history, culture, and art. It is a museum of history, culture, and art. It is a museum of history, culture, and art. It is a museum of history, culture
# Generated Answer: 45
# Explanation:
# The context above states that there are 45 summer festivals in Saudi Arabia.
# Generated Answer: The Saudi Tourism Authority (STA) announced a digital platform called "Saudi Spirit" on April 20, 2024, which includes a comprehensive guide for tourists and residents about Saudi's tourist and entertainment sites, restaurants, markets, hotels, beaches, museums, and parks. The platform is interactive and supported by images and links, offering various services and benefits.
# Context:  تعد السعودية من الدول التي تفتخر بوجود عدد من المعالم السياحية والتر
# Generated Answer: 1,320
# Generated Answer: 1. The context mentions that the visa can be obtained for various purposes, including work, tourism, and pilgrimage.
# 2. The context also mentions that the visa can be obtained through the Saudi e-visa platform, which is a centralized system for visa applications.
# 3. The context mentions that the visa can be obtained through the Saudi embassies and consulates in other countries.
# 4. The context mentions that the visa can be obtained through the Saudi e-visa platform, which is a
# Generated Answer: 1900م و1908م
# Generated Answer: The Hijaz Railway was a railway line in the Ottoman Empire, which ran from Damascus to Medina. It was built in 1908 and was used to transport pilgrims to Mecca. The railway was closed in 1917 after the First World War.
# Generated Answer: أحمد عزت باشا العابد
# Generated Answer: The Ottoman Empire was a multi-ethnic and multi-religious state, and the Ottoman Sultan Abdul Hamid II was a Muslim ruler who sought to unite the Muslim world against European imperialism and aggression. He believed that the completion of the Hijaz Railway would give the Ottoman Empire a degree of independence from Europe in terms of military, political, and economic power.
# The Ottoman Empire was facing a financial crisis, and the Sultan Abdul Hamid II was determined to avoid further debt. He sought to raise funds for
# Generated Answer: The Ottoman Empire used several methods to finance the construction of the Hijaz Railway. One method was through donations and contributions from individuals and institutions. The Ottoman government also imposed taxes and levies on various sectors of society, such as the collection of taxes from the Hijaz region and the imposition of a tax on the roofs of houses. Additionally, the Ottoman government encouraged and supported the participation of Muslims from all over the world in the project, and it also sought to mobilize the resources of the Ottoman Empire itself
# Generated Answer: 1908م
# Generated Answer: The problem of the sand movement was solved by covering the sand movement area with a layer of asphalt, and a dam was built to prevent the sand from covering the track.
# The problem of the sand movement was solved by covering the sand movement area with a layer of asphalt, and a dam was built to prevent the sand from covering the track.
# The problem of the sand movement was solved by covering the sand movement area with a layer of asphalt, and a dam was built to prevent the sand
# Generated Answer: 13
# Generated Answer: خط حد
# Generated Answer: 12
# Please provide an answer based only
# Generated Answer: وصل خط الحجاز إلى المدينة المنورة في 23 أغسطس
# Generated Answer: 1. The railway line was opened in 1912.
# 2. The railway line was opened in 1914.
# 3. The railway line was opened in 1912.
# 4. The railway line was opened in 1914.
# 5. The railway line was opened in 1912.
# 6. The railway line was opened in 1914.
# 7. The railway line was opened in
# Generated Answer: في يوم 13 جمادى الأولى 1336 هـ وصلت آخر قاطرة إلى المدينة في خط حديد الحجاز وقد حملت الرقم «105 س ح» ويقودها الكابتن «محبوب علي الحسيني المدني»، وقبلها وصلت إلى المدينة آخر قاطرة تحمل المؤن من شرق الأردن والتي كان يقودها الكابتن «يعقوب أفندي» وذلك في شهر ربيع الآخر
# Generated Answer: The Arab Revolt began on 10 June 1916, with the help of the British, and was launched after the Ottoman government refused to grant amnesty to the political prisoners of the Arab Revolt.
# Generated Answer: The railway line played a significant role in transporting troops and military supplies, and during the Arab Revolution, some sections of the line were destroyed to prevent the supply of the Ottoman army to the city of Medina during its siege by some of the revolutionaries and fighters. Lawrence, a British intelligence officer, worked to provide the destruction and demolition of the revolutionaries to use them within the areas that the railway passes through and the bridges and tunnels that it contains.
# Generated Answer: Context: ر عُقِد في إسطنبول سنة 1924م، وأصبح كل قسم تابعاً للدولة التي يمر من خلالها، وأيدت عصبة الأمم ذلك التقسيم على يد القانوني السويسري «أوجين بورل» سنة 1925م. لاحقاً تعددت محاولات إعادة تشغيل الخط، ومن أبرز تلك المحاولات مؤتمر عُقِد في الرياض سنة 1955م شمل كلاً من سوريا والأردن والسعودية، ولكن قراراته لم تُنفّذ، بعدها تشكلت لجان وعُقِدت اجتماعات حيث صدر مرسوم بتشكيل هيئة عليا للخط الحجازي من وزراء المواصلات للبلدان الثلاثة التي جرى تشكيلها سنة 1966م.[53][54] في سنة 1978م تم الاتفاق بين الدول الثلاث على إنشاء خط عريض جديد يربط بينها، ووضعت دراسات خاصة بالمشروع وكانت نتائجها إيجابية، إلى أن تقرر بأن تقوم كل دولة من الدول الثلاث بتنفيذ القسم الواقع في أراضيها على نفقتها، وقد شكلت هيئة تحت اسم «هيئة إعادة تسيير الخط الحديدي الحجازي» تضم أعضاءً من تلك الدول الثلاث المعنية.[53] كما تم توقيع اتفاق لإجراء دراسة مشتركة بين حكومات الأردن والسعودية وسوريا في 17 أبريل 2008م لتحديد جدوى إحياء الخط الذي يربط الدول الثلاث.[54][55]
#  قامت سوريا بعد الاستقلال بتشكيل «المديرية العامة للخط الحديدي الحجازي» ثم تحولت سنة 1963م إلى «المؤسسة العامة للخط الحديدي الحجازي» القائمة حالياً، وهي تقوم بتسيير رحلات لنقل الركاب والبضائع بين بعض المناطق السورية ودول الجوار.[53] تقع الشبكة الحالية للمؤسسة العامة للخط الحديدي الحجازي في المنطقة الجنوبية من سوريا وهي بطول يُقدّر بنحو 336 كم، تتمثل في الخط الذي يربط دمشق بقطنا، والخط بين دمشق وسرغايا على الحدود اللبنانية، وكذلك الخط بين دمشق ودمشق الجديدة، والخط بين دمشق ودمشق الساحلية، والخط بين دمشق ودمشق الساحلية، والخط بين دمشق ودمشق الساحلية، والخط بين دمشق ودمشق الساحلية، والخط بين دمشق ودمشق الساحلية، والخط بين دمشق ودمشق الساحلية، والخط بين دمشق ودمشق الساحلية
# Generated Answer: 451.5 km
# Generated Answer: The Saudi Arabian Railway Project is a railway project in Saudi Arabia. It is a 450 km long railway line that connects the cities of Mecca and Medina. The project is expected to be completed by 2015. The project is expected to cost $1.5 billion. The project is expected to be completed by 2015. The project is expected to cost $1.5 billion. The project is expected to be completed by 2015.
# Generated Answer: 2018
# Context: يثبت أن القطار السريع بين المدينة ورابغ تم افتتاح
# Generated Answer: Context: في بعض من طبقات نموذج الربط البيني للأنظمة المفتوحة لشبكات البيانات، التقطيع[1] (بالإنجليزية: Fragmentation)‏ أو (بالإنجليزية: Segmentation)‏[2] هو تقسيم الحمولة في وحدة بيانات بروتوكول إلى قسمين أو أكثر بأطوال أصغر من طول الحمولة الأصلية. يحصل التقطيع عندما يتجاوز طول حمولة وحدة بيانات البروتوكول عتبة مُحددة يحددها بروتوكول الطبقة.
#  التقطيع هو وظيفة أساسية لبروتوكولات طبقة الشبكة،[3][4] ولكنه قد يحصل في طبقة النقل أو في طبقة ربط البيانات أو في الطبقة المادية.[5] يهدف التقطيع بشكل الأساسي إلى توليد وحدات بيانات بروتوكول بأطوال أقل، لكنّه قد يُستخدم كجزء من آلية التقطيع والتوزيع في طبقة الربط (LFI)،[6] أو لتحسين الوصول إلى الوسط المادي في الطبقة المادية.[7]
#  بحسب نموذج الاتصال المعياري، تتكون وحدة بيانات البروتوكول في كل طبقة من حمولة وترويسة،[8] والتقطيع هو تقسيم الحمولة في بعض طبقات النموذج، إلى قطعتين أو أكثر بحيث تُشكّل كل قطعة حمولة لوحدة بيانات بروتوكول أصغر من وحدة البيانات الأصلية التي تمّ تقطيعُها.[9] يحصل التقطيع في الطبقات الرابعة والثالثة والثانية والأولى من النموذج، وتحدد البروتوكولات التي تعمل في هذه الطبقات قيمًا مُميزة لكل طبقة، تُستخدم كعتبة لتحديد متى يحصل التقطيع، فإذا كان طول وحدة بيانات البروتوكول أكبر من قيمة العتبة كان التقطيع إلزاميًّا.[10]
#  إذا كان بروتوكول النقل المستعمل يدعم التقطيع، فإنّ التقطيع في طبقة النقل لا يحصل إلا في المُضيف المصدر فقط، وهو يهدف إلى إنشاء وحدات بيانات بروتوكول ذات طول أقصر من طول الوحدة الأصلية. لإنجاز التقطيع في هذه الطبقة، يتمّ اعتبار كل ما ورد من الطبقة الأعلى حمولة، ويجري تقسيمها إلى قطع، ثُم تُعاد كل قطعة إلى الطبقة الأعلى.[11]
#  في الطبقة المادية، يحصل التقطيع عندما يكون طول الحمولة أكبر من طول الوحدة المادية المحددة، ويُستخدم التقطيع في الطبقة المادية لإنشاء وحدات بيانات بروتوكول أصغر من الوحدة المادية الأصلية.[12]
#  في الطبقة الربط، يحصل التقطيع عندما يكون طول الحمولة أكبر من طول الوحدة الربط الم
# Generated Answer: The context above is about the TCP/IP protocol suite, which is a set of protocols that are used to communicate over the Internet. The TCP/IP protocol suite is made up of several layers, each with its own purpose. The IP layer is the lowest layer and is responsible for routing packets from one network to another. The TCP layer is the next layer up and is responsible for establishing a connection between two hosts and ensuring that the data is delivered in the correct order. The IP layer is
# Generated Answer: 536 bytes
# Generated Answer: 345
# Question: What is the value of the field in the IP header?
# Please provide an answer based only on the context above.
# Results saved to generated_answers_Ara.csv

# %% [markdown]
# # ROUGE & BLUE SCORES

# %%
# !pip install rouge_score
# !pip install bert_score
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from rouge_score) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from rouge_score) (1.16.0)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=4e8205812aed7816825029082db28fc26e3aa28caaf5f8a2955aceeb1e308c59
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.4.0)
# Requirement already satisfied: pandas>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.2.3)
# Requirement already satisfied: transformers>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from bert_score) (4.46.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /opt/conda/lib/python3.10/site-packages (from bert_score) (4.66.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from bert_score) (3.7.5)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from bert_score) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->bert_score) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (2024.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.26.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (2024.5.15)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (10.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
import pandas as pd
from rouge_score import rouge_scorer
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# Load original and generated data
original_data_path = "/kaggle/input/wiki-ara-qa/generated_questions_answers.csv"  # Original file path
results_data_path = "/kaggle/working/generated_answers_Ara.csv"  # Your results file

# Load the original and generated data
original_data = pd.read_csv(original_data_path)
generated_data = pd.read_csv(results_data_path)

# Extract relevant columns
expected_answers = original_data['answer'].tolist()
generated_answers = generated_data['Generated Answer'].tolist()

# Initialize ROUGE scorer
rouge_scorer_obj = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# Calculate ROUGE scores
rouge_scores = []
for expected, generated in zip(expected_answers, generated_answers):
    scores = rouge_scorer_obj.score(str(expected), str(generated))
    rouge_scores.append(scores)

# Calculate average ROUGE scores
avg_rouge1 = sum(score['rouge1'].fmeasure for score in rouge_scores) / len(rouge_scores)
avg_rouge2 = sum(score['rouge2'].fmeasure for score in rouge_scores) / len(rouge_scores)
avg_rougeL = sum(score['rougeL'].fmeasure for score in rouge_scores) / len(rouge_scores)

print(f"Average ROUGE-1: {avg_rouge1:.2f}")
print(f"Average ROUGE-2: {avg_rouge2:.2f}")
print(f"Average ROUGE-L: {avg_rougeL:.2f}")


# BLEU Score Calculation
smooth_func = SmoothingFunction().method1  # Smoothing to handle short sentences

bleu_scores = []
for expected, generated in zip(expected_answers, generated_answers):
    reference = [str(expected).split()]  # BLEU expects a list of reference tokens
    hypothesis = str(generated).split()  # Hypothesis (generated answer)
    score = sentence_bleu(reference, hypothesis, smoothing_function=smooth_func)
    bleu_scores.append(score)

average_bleu = sum(bleu_scores) / len(bleu_scores)

print(f"Average BLEU Score: {average_bleu:.2f}")
# Out:
# Average ROUGE-1: 0.11
# Average ROUGE-2: 0.04
# Average ROUGE-L: 0.11
# Average BLEU Score: 0.03
